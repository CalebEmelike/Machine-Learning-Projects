# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datasist as ds
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline
pd.set_option('max_colwidth', 1000)

# %%
train = pd.read_csv("Train.csv")
test = pd.read_csv("Test.csv")
riders = pd.read_csv("Riders.csv")
sample = pd.read_csv("SampleSubmission.csv")
datadef = pd.read_csv("VariableDefinitions.csv")

# %%
train.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# ...

# %%
train.describe()
# Out:
#        Platform Type  Placement - Day of Month  Placement - Weekday (Mo = 1)  \
# count   21201.000000              21201.000000                  21201.000000
# mean        2.752182                 15.653696                      3.240083
# std         0.625178                  8.798916                      1.567295
# min         1.000000                  1.000000                      1.000000
# 25%         3.000000                  8.000000                      2.000000
# 50%         3.000000                 15.000000                      3.000000
# 75%         3.000000                 23.000000                      5.000000
# max         4.000000                 31.000000                      7.000000
#
#        Confirmation - Day of Month  Confirmation - Weekday (Mo = 1)  \
# count                 21201.000000                     21201.000000
# mean                     15.653837                         3.240225
# std                       8.798886                         1.567228
# ...

# %%
test.describe()
# Out:
#        Platform Type  Placement - Day of Month  Placement - Weekday (Mo = 1)  \
# count    7068.000000               7068.000000                   7068.000000
# mean        2.752122                 15.621817                      3.249859
# std         0.624000                  8.776650                      1.580926
# min         1.000000                  1.000000                      1.000000
# 25%         3.000000                  8.000000                      2.000000
# 50%         3.000000                 15.000000                      3.000000
# 75%         3.000000                 23.000000                      5.000000
# max         4.000000                 31.000000                      7.000000
#
#        Confirmation - Day of Month  Confirmation - Weekday (Mo = 1)  \
# count                  7068.000000                      7068.000000
# mean                     15.621817                         3.249859
# std                       8.776650                         1.580926
# ...

# %%
train.columns
# Out:
# Index(['Order No', 'User Id', 'Vehicle Type', 'Platform Type',
#        'Personal or Business', 'Placement - Day of Month',
#        'Placement - Weekday (Mo = 1)', 'Placement - Time',
#        'Confirmation - Day of Month', 'Confirmation - Weekday (Mo = 1)',
#        'Confirmation - Time', 'Arrival at Pickup - Day of Month',
#        'Arrival at Pickup - Weekday (Mo = 1)', 'Arrival at Pickup - Time',
#        'Pickup - Day of Month', 'Pickup - Weekday (Mo = 1)', 'Pickup - Time',
#        'Arrival at Destination - Day of Month',
#        'Arrival at Destination - Weekday (Mo = 1)',
#        'Arrival at Destination - Time', 'Distance (KM)', 'Temperature',
#        'Precipitation in millimeters', 'Pickup Lat', 'Pickup Long',
#        'Destination Lat', 'Destination Long', 'Rider Id',
#        'Time from Pickup to Arrival'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['Order No', 'User Id', 'Vehicle Type', 'Platform Type',
#        'Personal or Business', 'Placement - Day of Month',
#        'Placement - Weekday (Mo = 1)', 'Placement - Time',
#        'Confirmation - Day of Month', 'Confirmation - Weekday (Mo = 1)',
#        'Confirmation - Time', 'Arrival at Pickup - Day of Month',
#        'Arrival at Pickup - Weekday (Mo = 1)', 'Arrival at Pickup - Time',
#        'Pickup - Day of Month', 'Pickup - Weekday (Mo = 1)', 'Pickup - Time',
#        'Distance (KM)', 'Temperature', 'Precipitation in millimeters',
#        'Pickup Lat', 'Pickup Long', 'Destination Lat', 'Destination Long',
#        'Rider Id'],
#       dtype='object')

# %%
#Drop
col_2_drop = ['Arrival at Destination - Day of Month', 'Arrival at Destination - Weekday (Mo = 1)']
train.drop(col_2_drop, axis=1, inplace=True)

# %%
#Merge riders dataset to train and test datasets
train_merged = train.merge(riders, how='left', on='Rider Id')
test_merged = test.merge(riders, how='left', on='Rider Id')

# %%
ds.feature_engineering.drop_redundant(train_merged)
ds.feature_engineering.drop_redundant(test_merged)
# Out:
# Dropped ['Vehicle Type']
# Dropped ['Vehicle Type']

# %%
ds.feature_engineering.drop_missing(train_merged, percent=80)
ds.feature_engineering.drop_missing(test_merged, percent=80)
# Out:
# Dropped ['Precipitation in millimeters']
# Dropped ['Precipitation in millimeters']

# %%
#Get columns
cat_cols = ds.structdata.get_cat_feats(train_merged)
num_cols = ds.structdata.get_num_feats(train_merged)

time_cols = ['Pickup - Time', 'Arrival at Pickup - Time', 
             'Confirmation - Time', 'Placement - Time', 'Arrival at Destination - Time']

# %%
train_merged.drop(columns=['Order No', 'User Id'], inplace=True)
test_merged.drop(columns=['Order No', 'User Id'], inplace=True)

# %%
train_merged.head()
# Out:
#    Platform Type Personal or Business  Placement - Day of Month  \
# 0              3             Business                         9
# 1              3             Personal                        12
# 2              3             Business                        30
# 3              3             Business                        15
# 4              1             Personal                        13
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# 2                             2      12:39:25 PM                           30
# 3                             5       9:25:34 AM                           15
# 4                             1       9:55:18 AM                           13
#
#    Confirmation - Weekday (Mo = 1) Confirmation - Time  \
# ...

# %%
train_merged['Arrival at Destination - Time'].head()
# Out:
# 0    10:39:55 AM
# 1    12:17:22 PM
# 2     1:00:38 PM
# 3    10:05:27 AM
# 4    10:25:37 AM
# Name: Arrival at Destination - Time, dtype: object

# %%
#get hours, minute and seconds from time columns
cols = time_cols
train_merged = ds.timeseries.extract_time(data=train_merged, time_cols=cols)
test_merged = ds.timeseries.extract_time(data=test_merged, time_cols=cols)

# %%
train_merged.head()
# Out:
#    Platform Type Personal or Business  Placement - Day of Month  \
# 0              3             Business                         9
# 1              3             Personal                        12
# 2              3             Business                        30
# 3              3             Business                        15
# 4              1             Personal                        13
#
#    Placement - Weekday (Mo = 1)    Placement - Time  \
# 0                             5 2019-11-21 09:35:46
# 1                             5 2019-11-21 11:16:16
# 2                             2 2019-11-21 12:39:25
# 3                             5 2019-11-21 09:25:34
# 4                             1 2019-11-21 09:55:18
#
#    Confirmation - Day of Month  Confirmation - Weekday (Mo = 1)  \
# 0                            9                                5
# 1                           12                                5
# 2                           30                                2
# ...

# %%
test_merged.head()
# Out:
#    Platform Type Personal or Business  Placement - Day of Month  \
# 0              3             Business                        27
# 1              3             Business                        17
# 2              3             Business                        27
# 3              3             Business                        17
# 4              3             Business                        11
#
#    Placement - Weekday (Mo = 1)    Placement - Time  \
# 0                             3 2019-11-21 16:44:10
# 1                             5 2019-11-21 12:57:35
# 2                             4 2019-11-21 11:08:14
# 3                             1 2019-11-21 13:51:35
# 4                             2 2019-11-21 11:30:28
#
#    Confirmation - Day of Month  Confirmation - Weekday (Mo = 1)  \
# 0                           27                                3
# 1                           17                                5
# 2                           27                                4
# ...
